# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np
# %matplotlib inline

# %%
df = pd.read_csv(r"C:\Users\lenovo\OneDrive\Desktop\BIT\Python\Datasets\Zomato Dataset\zomato.csv" , encoding = "ISO-8859-1")

# %%
df
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730              NamlÛ± Gurme           208         ÛÁstanbul
# 9547        5908749             Ceviz AÛôacÛ±           208         ÛÁstanbul
# 9548        5915807                     Huqqa           208         ÛÁstanbul
# 9549        5916112              Aôôk Kahve           208         ÛÁstanbul
# 9550        5927402  Walter's Coffee Roastery           208         ÛÁstanbul
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
df['Has Table booking']=df['Has Table booking'].map({'Yes':0 , 'No':1})

# %%
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
df['Has Online delivery']=df['Has Online delivery'].map({'Yes':0 , 'No':1})

# %%
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
df['Is delivering now'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
df['Is delivering now']=df['Is delivering now'].map({'Yes':0 , 'No':1})

# %%
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
df['Switch to order menu'].unique()
# Out:
# array(['No'], dtype=object)

# %%
df['Switch to order menu']=df['Switch to order menu'].map({'No':0})

# %%
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   int64
#  13  Has Online delivery   9551 non-null   int64
#  14  Is delivering now     9551 non-null   int64
# ...

# %%
df['Rating color'].unique()
# Out:
# array(['Dark Green', 'Green', 'Yellow', 'Orange', 'White', 'Red'],
#       dtype=object)

# %%
df['Rating color']=df['Rating color'].map({'Dark Green':0 , 'Green':1 , 'Yellow':2 , 'Orange':3 , 'White':4 , 'Red':5})

# %%
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
df['Rating text'].unique()
# Out:
# array(['Excellent', 'Very Good', 'Good', 'Average', 'Not rated', 'Poor'],
#       dtype=object)

# %%
df['Rating text']=df['Rating text'].map({'Excellent':0 , 'Very Good':1 , 'Good':2 , 'Average':3 , 'Not rated':4 , 'Poor':5})

# %%
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   int64
#  13  Has Online delivery   9551 non-null   int64
#  14  Is delivering now     9551 non-null   int64
# ...

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder = LabelEncoder()

# %%
df['Currency'] = labelencoder.fit_transform(df['Currency'])

# %%
df['Cuisines'] = labelencoder.fit_transform(df['Cuisines'])

# %%
df['Locality Verbose'] = labelencoder.fit_transform(df['Locality Verbose'])
df['Locality'] = labelencoder.fit_transform(df['Locality'])
df['Address'] = labelencoder.fit_transform(df['Address'])
df['City'] = labelencoder.fit_transform(df['City'])
df['Restaurant Name'] = labelencoder.fit_transform(df['Restaurant Name'])

# %%
df.head()
# Out:
#    Restaurant ID  Restaurant Name  Country Code  City  Address  Locality  \
# 0        6317637             3749           162    73     8685       171
# 1        6304287             3173           162    73     6055       593
# 2        6300002             2897           162    75     4684       308
# 3        6318506             4707           162    75     8690       862
# 4        6314302             5523           162    75     8689       862
#
#    Locality Verbose   Longitude   Latitude  Cuisines  ...  Currency  \
# 0               172  121.027535  14.565443       920  ...         0
# 1               601  121.014101  14.553708      1111  ...         0
# 2               314  121.056831  14.581404      1671  ...         0
# 3               875  121.056475  14.585318      1126  ...         0
# 4               875  121.057508  14.584450      1122  ...         0
#
#    Has Table booking  Has Online delivery  Is delivering now  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   int32
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   int32
#  4   Address               9551 non-null   int32
#  5   Locality              9551 non-null   int32
#  6   Locality Verbose      9551 non-null   int32
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9551 non-null   int32
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   int32
#  12  Has Table booking     9551 non-null   int64
#  13  Has Online delivery   9551 non-null   int64
#  14  Is delivering now     9551 non-null   int64
# ...

# %%
df.head()
# Out:
#    Restaurant ID  Restaurant Name  Country Code  City  Address  Locality  \
# 0        6317637             3749           162    73     8685       171
# 1        6304287             3173           162    73     6055       593
# 2        6300002             2897           162    75     4684       308
# 3        6318506             4707           162    75     8690       862
# 4        6314302             5523           162    75     8689       862
#
#    Locality Verbose   Longitude   Latitude  Cuisines  ...  Currency  \
# 0               172  121.027535  14.565443       920  ...         0
# 1               601  121.014101  14.553708      1111  ...         0
# 2               314  121.056831  14.581404      1671  ...         0
# 3               875  121.056475  14.585318      1126  ...         0
# 4               875  121.057508  14.584450      1122  ...         0
#
#    Has Table booking  Has Online delivery  Is delivering now  \
# ...

# %%
df['Price range'].plot(kind = 'box', figsize=(10,5))
# Out:
# <AxesSubplot:>

# %%
df.iloc[5:11].plot(kind = 'bar', figsize = (20,10))
# Out:
# <AxesSubplot:>

# %%
df.hist(figsize = (20,10), color = 'r', alpha = 0.8)
# Out:
# array([[<AxesSubplot:title={'center':'Restaurant ID'}>,
#         <AxesSubplot:title={'center':'Restaurant Name'}>,
#         <AxesSubplot:title={'center':'Country Code'}>,
#         <AxesSubplot:title={'center':'City'}>,
#         <AxesSubplot:title={'center':'Address'}>],
#        [<AxesSubplot:title={'center':'Locality'}>,
#         <AxesSubplot:title={'center':'Locality Verbose'}>,
#         <AxesSubplot:title={'center':'Longitude'}>,
#         <AxesSubplot:title={'center':'Latitude'}>,
#         <AxesSubplot:title={'center':'Cuisines'}>],
#        [<AxesSubplot:title={'center':'Average Cost for two'}>,
#         <AxesSubplot:title={'center':'Currency'}>,
#         <AxesSubplot:title={'center':'Has Table booking'}>,
#         <AxesSubplot:title={'center':'Has Online delivery'}>,
#         <AxesSubplot:title={'center':'Is delivering now'}>],
#        [<AxesSubplot:title={'center':'Switch to order menu'}>,
#         <AxesSubplot:title={'center':'Price range'}>,
# ...

# %%
sns.distplot(df['Aggregate rating'].dropna(),kde=True,bins=20,color = 'blue')
# Out:
# D:\Anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Aggregate rating', ylabel='Density'>

# %%
sns.barplot(x = 'Price range' , y = 'Aggregate rating' , data = df)
# Out:
# <AxesSubplot:xlabel='Price range', ylabel='Aggregate rating'>

# %%
sns.histplot(x = 'Price range' , y = 'Aggregate rating' , data = df)
# Out:
# <AxesSubplot:xlabel='Price range', ylabel='Aggregate rating'>

# %%
df.head()
# Out:
#    Restaurant ID  Restaurant Name  Country Code  City  Address  Locality  \
# 0        6317637             3749           162    73     8685       171
# 1        6304287             3173           162    73     6055       593
# 2        6300002             2897           162    75     4684       308
# 3        6318506             4707           162    75     8690       862
# 4        6314302             5523           162    75     8689       862
#
#    Locality Verbose   Longitude   Latitude  Cuisines  ...  Currency  \
# 0               172  121.027535  14.565443       920  ...         0
# 1               601  121.014101  14.553708      1111  ...         0
# 2               314  121.056831  14.581404      1671  ...         0
# 3               875  121.056475  14.585318      1126  ...         0
# 4               875  121.057508  14.584450      1122  ...         0
#
#    Has Table booking  Has Online delivery  Is delivering now  \
# ...

# %%
df.plot(x = 'Has Online delivery')
# Out:
# <AxesSubplot:xlabel='Has Online delivery'>

# %%
sns.distplot(df['Currency'].dropna(),kde=True,bins=20,color = 'blue')
# Out:
# D:\Anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Currency', ylabel='Density'>

# %%
sns.countplot(x = 'Has Online delivery' , data = df)
# Out:
# <AxesSubplot:xlabel='Has Online delivery', ylabel='count'>

# %%
sns.countplot(x = 'Has Table booking' , data = df)
# Out:
# <AxesSubplot:xlabel='Has Table booking', ylabel='count'>

# %%
sns.countplot(x = 'Is delivering now' , data = df)
# Out:
# <AxesSubplot:xlabel='Is delivering now', ylabel='count'>

# %%
sns.countplot(x = 'Rating color' , data = df)
# Out:
# <AxesSubplot:xlabel='Rating color', ylabel='count'>

# %%
sns.countplot(x = 'Price range' , data = df)
# Out:
# <AxesSubplot:xlabel='Price range', ylabel='count'>

# %%
plt.figure(figsize=(8,4))
sns.countplot(x='Aggregate rating' , data = df , palette = 'RdBu_r' , hue = 'Rating color')
# Out:
# <AxesSubplot:xlabel='Aggregate rating', ylabel='count'>

# %%
x = df['Aggregate rating']
y = df['Rating color']
plt.scatter(x,y)
plt.xlabel('Aggregate rating' , fontsize = 12)
plt.ylabel('Rating color' , fontsize = 12)
# Out:
# Text(0, 0.5, 'Rating color')
